# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport
from matplotlib import pyplot as plt

# %%
#Automatically generate some rough analysis of the data
df = pd.read_csv("./data/clean_ballot_qs.csv")
profile = ProfileReport(df, title="ballot_qs_eda")
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.11.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-10-17 18:07:07.442259&quot;&gt;&lt;title&gt;ballot_qs_eda&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
states = np.unique(df["State"])
print(len(states))
print(states)
# Out:
# 50
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'District of Columbia' 'Florida' 'Georgia' 'Hawaii' 'Idaho'
#  'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine'
#  'Maryland' 'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi'
#  'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey'
#  'New Mexico' 'New York' 'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma'
#  'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina' 'South Dakota'
#  'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia' 'Washington'
#  'West Virginia' 'Wisconsin' 'Wyoming']

# %% [markdown]
# We have all states except Delaware in our dataset. And that is because Delaware does not allow ballot measures.

# %%
state_count = df["State"].value_counts()

print(state_count)
# Out:
# State
# California              201
# Louisiana               155
# Texas                   137
# Oregon                  134
# Colorado                132
# Maine                   109
# Washington              108
# Arizona                 106
# Alabama                  96
# New Mexico               90
# Florida                  78
# Rhode Island             75
# South Dakota             70
# Missouri                 68
# Oklahoma                 67
# Georgia                  65
# Nevada                   59
# North Dakota             53
# Nebraska                 51
# Montana                  50
# Utah                     47
# Arkansas                 44
# Alaska                   42
# Ohio                     41
# Massachusetts            40
# Michigan                 37
# New Jersey               35
# Maryland                 33
# Hawaii                   26
# South Carolina           26
# Idaho                    25
# New York                 24
# Virginia                 23
# ...

# %%
df[df["Year"]>2019]["State"].value_counts()
# Out:
# State
# Colorado                27
# Louisiana               27
# Texas                   24
# California              20
# Alabama                 18
# Arizona                 12
# Maine                   11
# New Mexico              11
# Washington              11
# Rhode Island            11
# Missouri                10
# Nebraska                 9
# Florida                  9
# Oregon                   8
# Nevada                   8
# New York                 8
# Utah                     8
# Arkansas                 7
# Wisconsin                7
# Maryland                 7
# Georgia                  7
# Montana                  6
# South Dakota             6
# Massachusetts            6
# New Jersey               5
# Michigan                 5
# Ohio                     5
# North Dakota             5
# Kentucky                 4
# West Virginia            4
# Pennsylvania             4
# Tennessee                4
# Wyoming                  3
# Mississippi              3
# ...
